# %%
from src.IrisData import IrisData
data = IrisData()

# %% [markdown]
# # k-means clustering

# %%
from src.KMeansClustering import *
kMeans = KMeansClustering(data, k = 3, maxItr = 100)
kMeans.run()

# %%
import matplotlib.pyplot as plt
plt.plot(kMeans.objFunc, "o-r")
plt.ylabel("Objective Function")
plt.xlabel("Iteration")
plt.show()

# %%
graphShaded = False
if graphShaded:
    for i in range(2, 6):
        print(f"k = {i}")
        kMeans = KMeansClustering(data, k = i, maxItr = 100)
        kMeans.run(withFigure=False)
        _ = kMeans.plotClusters()
        _ = kMeans.plotClusters(shading=True)

# %% [markdown]
# # Neural Networks

# %%
from src.NeuralNetwork import *

# %%
dataset = data.getData()
dataset.switchToNeuralNetwork()

network = NeuralNetwork(weights=np.asarray([-0.7, -0.5,  1.9,  1.5]))
Training.plotClassification(dataset.getPoints(), network)
records = Training.train(dataset.getPoints(), network, dataset.getLabels(), 1000)
Training.plotClassification(dataset.getPoints(), network)

network = NeuralNetwork(weights=np.asarray([-3.978, -3.467,  5.316, 5.326]))
Training.plotClassification(dataset.getPoints(), network)

iterations, errors = zip(*records)
fig, ax = plt.subplots()
ax.plot(iterations, errors)
ax.set_title("MSE vs Iteration")
ax.set_xlabel("Iteration")
ax.set_ylabel("MSE")
# Out:
# 0 --- [0.079, 0.0368, 0.054, 0.0167] --- 0.4694 --- [-0.77904466 -0.53675697  1.84595198  1.48334066]
# 20 --- [-0.1375, -0.0631, -0.119, -0.0451] --- 0.3864 --- [-1.65420474 -0.97548189  1.58358136  1.52609514]
# 40 --- [-0.4207, -0.1912, -0.3625, -0.1358] --- 0.1562 --- [-1.48394256 -0.9338955   2.17292153  1.87839584]
# 60 --- [-0.7773, -0.3499, -0.6557, -0.2391] --- 0.4899 --- [-1.25202245 -0.88389343  2.89622449  2.31185838]
# 80 --- [0.4475, 0.2107, 0.3303, 0.1032] --- 0.3923 --- [-2.4527287  -1.4921877   2.51508562  2.36423638]
# 100 --- [0.6106, 0.2835, 0.4321, 0.1327] --- 0.3215 --- [-2.73569256 -1.68810305  2.98034581  2.73178916]
# 120 --- [0.5877, 0.2734, 0.4187, 0.129] --- 0.2651 --- [-3.00460148 -1.88662562  3.39790105  3.08394568]
# 140 --- [0.4372, 0.2055, 0.3233, 0.1016] --- 0.2034 --- [-3.21885439 -2.06202954  3.7663496   3.39810829]
# 160 --- [0.5047, 0.2362, 0.366, 0.114] --- 0.1544 --- [-3.43661482 -2.2481914   4.13758547  3.71625392]
# 180 --- [0.4431, 0.2081, 0.3252, 0.102] --- 0.1134 --- [-3.60557933 -2.42152002  4.46055905  4.00027359]
# 200 --- [0.3265, 0.1537, 0.2449, 0.0774] --- 0.0796 --- [-3.67532455 -2.53368386  4.66537441  4.20065115]
# 220 --- [0.2529, 0.1191, 0.1919, 0.0609] --- 0.0621 --- [-3.70076649 -2.60252869  4.77742468  4.33463554]
# 240 --- [0.212, 0.0999, 0.1619, 0.0515] --- 0.0538 --- [-3.71675593 -2.65616477  4.84738964  4.4350176 ]
# 260 --- [0.1839, 0.0868, 0.141, 0.0449] --- 0.0489 --- [-3.7271622  -2.70206108  4.89832923  4.51712447]
# 280 --- [0.1621, 0.0766, 0.1247, 0.0397] --- 0.0454 --- [-3.73363179 -2.74308819  4.93849081  4.58720896]
# 300 --- [0.1441, 0.0682, 0.111, 0.0354] --- 0.0429 --- [-3.73718804 -2.78068499  4.97171962  4.64854663]
# 320 --- [0.1285, 0.0609, 0.0992, 0.0316] --- 0.0408 --- [-3.73850953 -2.81566816  5.00014566  4.70313825]
# 340 --- [0.1145, 0.0544, 0.0884, 0.0281] --- 0.0392 --- [-3.7380678  -2.84853894  5.02508328  4.75232799]
# 360 --- [0.1015, 0.0484, 0.0785, 0.0249] --- 0.0378 --- [-3.73620146 -2.87962198  5.04740766  4.79708092]
# 380 --- [0.0893, 0.0427, 0.0691, 0.0219] --- 0.0366 --- [-3.73315913 -2.90913577  5.06773738  4.83812644]
# 400 --- [0.0776, 0.0373, 0.0601, 0.0189] --- 0.0356 --- [-3.72912695 -2.93723218  5.0865322   4.87604056]
# 420 --- [0.066, 0.0319, 0.0511, 0.016] --- 0.0347 --- [-3.72425023 -2.96402136  5.10414825  4.91129744]
# 440 --- [0.0546, 0.0266, 0.0422, 0.013] --- 0.034 --- [-3.71865812 -2.98959181  5.12086642  4.94430373]
# 460 --- [0.0432, 0.0213, 0.0333, 0.0101] --- 0.0333 --- [-3.71250363 -3.01403409  5.13689574  4.97542086]
# 480 --- [0.0319, 0.016, 0.0245, 0.0072] --- 0.0328 --- [-3.7060333  -3.03747649  5.1523446   5.00497319]
# 500 --- [0.0214, 0.0111, 0.0163, 0.0044] --- 0.0324 --- [-3.69967651 -3.06012922  5.16716395  5.03323703]
# 520 --- [0.0125, 0.007, 0.0094, 0.0021] --- 0.0321 --- [-3.69405299 -3.08229185  5.18113034  5.0604184 ]
# 540 --- [0.0062, 0.004, 0.0044, 0.0004] --- 0.032 --- [-3.68973382 -3.10424683  5.19399694  5.08666012]
# 560 --- [0.0025, 0.0023, 0.0015, -0.0005] --- 0.0318 --- [-3.68687334 -3.1260906   5.20575526  5.11209557]
# 580 --- [0.0008, 0.0015, 0.0002, -0.001] --- 0.0317 --- [-3.68516716 -3.14771143  5.21668451  5.13687912]
# 600 --- [0.0002, 0.0012, -0.0003, -0.0011] --- 0.0316 --- [-3.68417404 -3.16893493  5.22713742  5.16115303]
# 620 --- [0.0, 0.001, -0.0005, -0.0012] --- 0.0315 --- [-3.68357822 -3.18964373  5.23735883  5.18501205]
# 640 --- [-0.0, 0.001, -0.0005, -0.0012] --- 0.0314 --- [-3.68322508 -3.20979375  5.24746555  5.20850513]
# 660 --- [-0.0, 0.001, -0.0005, -0.0011] --- 0.0313 --- [-3.68305521 -3.22938371  5.2574996   5.23165526]
# 680 --- [0.0, 0.0009, -0.0005, -0.0011] --- 0.0312 --- [-3.68304711 -3.24842872  5.26747334  5.25447498]
# 700 --- [0.0, 0.0009, -0.0005, -0.0011] --- 0.0311 --- [-3.68319061 -3.26694809  5.27739032  5.27697353]
# 720 --- [0.0, 0.0009, -0.0005, -0.0011] --- 0.031 --- [-3.68347836 -3.28496141  5.28725206  5.29915915]
# 740 --- [0.0, 0.0009, -0.0005, -0.0011] --- 0.0309 --- [-3.6839037  -3.30248764  5.29705959  5.32103965]
# 760 --- [0.0, 0.0008, -0.0005, -0.0011] --- 0.0308 --- [-3.68446031 -3.31954494  5.30681385  5.34262254]
# 780 --- [0.0, 0.0008, -0.0005, -0.0011] --- 0.0307 --- [-3.68514212 -3.33615074  5.3165157   5.36391505]
# 800 --- [0.0, 0.0008, -0.0005, -0.001] --- 0.0306 --- [-3.68594328 -3.35232171  5.32616592  5.38492415]
# 820 --- [0.0, 0.0008, -0.0005, -0.001] --- 0.0305 --- [-3.68685821 -3.36807383  5.33576525  5.40565654]
# 840 --- [0.0001, 0.0008, -0.0005, -0.001] --- 0.0304 --- [-3.68788152 -3.38342242  5.3453144   5.42611872]
# 860 --- [0.0001, 0.0007, -0.0005, -0.001] --- 0.0303 --- [-3.68900806 -3.39838214  5.35481401  5.44631695]
# 880 --- [0.0001, 0.0007, -0.0005, -0.001] --- 0.0303 --- [-3.69023288 -3.41296706  5.36426468  5.46625727]
# 900 --- [0.0001, 0.0007, -0.0005, -0.001] --- 0.0302 --- [-3.69155122 -3.42719066  5.37366701  5.48594555]
# 920 --- [0.0001, 0.0007, -0.0005, -0.001] --- 0.0301 --- [-3.69295854 -3.44106588  5.38302152  5.50538743]
# 940 --- [0.0001, 0.0007, -0.0005, -0.001] --- 0.03 --- [-3.69445046 -3.45460511  5.39232873  5.52458838]
# 960 --- [0.0001, 0.0007, -0.0005, -0.0009] --- 0.03 --- [-3.69602281 -3.46782025  5.40158915  5.54355372]
# 980 --- [0.0001, 0.0006, -0.0005, -0.0009] --- 0.0299 --- [-3.69767156 -3.48072272  5.41080322  5.56228857]
# Text(0, 0.5, 'MSE')

# %%
network = NeuralNetwork(weights=np.asarray([-4.12, -3.91, 5.61, 5.76]))
Training.plotClassification(dataset.getPoints(), network)
print(Training.MSE(dataset.getPoints(), network, dataset.getLabels()))

network = NeuralNetwork(weights=np.asarray([0.076, -0.078, 1.10, 0.73]))
Training.plotClassification(dataset.getPoints(), network)
print(Training.MSE(dataset.getPoints(), network, dataset.getLabels()))
# Out:
# 0.033845995641914005
# 0.49655874348811097
